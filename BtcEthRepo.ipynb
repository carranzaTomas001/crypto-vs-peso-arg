# %%
# Antes: la columna es texto
btc['snapped_at']  →  "2013-04-28 00:00:00 UTC"

# Después de parsear: es una fecha real con la que podés operar
btc['date'] = pd.to_datetime(btc['snapped_at']).dt.date
btc['date']  →  2013-04-28
